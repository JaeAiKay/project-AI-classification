# %%
import sklearn.feature_selection as feature_selection
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('cow.csv')
df.drop(columns=['hospital_number', ], inplace=True)
df
# Out:
#     surgery    age  temperature  pulse  respiratory_rate temp_of_extremities  \
# 0        no  adult         38.5   66.0              28.0                cool
# 1       yes  adult         39.2   88.0              20.0                 NaN
# 2        no  adult         38.3   40.0              24.0              normal
# 3       yes  young         39.1  164.0              84.0                cold
# 4        no  adult         37.3  104.0              35.0                 NaN
# ..      ...    ...          ...    ...               ...                 ...
# 294     yes  adult          NaN  120.0              70.0                cold
# 295      no  adult         37.2   72.0              24.0                cool
# 296     yes  adult         37.5   72.0              30.0                cold
# 297     yes  adult         36.5  100.0              24.0                cool
# 298     yes  adult         37.2   40.0              20.0                 NaN
#
#     peripheral_pulse mucous_membrane capillary_refill_time          pain  ...  \
# 0            reduced             NaN            more_3_sec  extreme_pain  ...
# 1                NaN   pale_cyanotic            less_3_sec     mild_pain  ...
# 2             normal       pale_pink            less_3_sec     mild_pain  ...
# 3             normal   dark_cyanotic            more_3_sec     depressed  ...
# 4                NaN   dark_cyanotic            more_3_sec           NaN  ...
# ..               ...             ...                   ...           ...  ...
# 294              NaN   pale_cyanotic            more_3_sec     depressed  ...
# 295        increased   pale_cyanotic            more_3_sec   severe_pain  ...
# 296          reduced   pale_cyanotic            less_3_sec   severe_pain  ...
# 297          reduced       pale_pink            less_3_sec     mild_pain  ...
# 298              NaN             NaN                   NaN           NaN  ...
#
#     nasogastric_reflux_ph rectal_exam_feces        abdomen packed_cell_volume  \
# 0                     NaN         decreased  distend_large               45.0
# 1                     NaN            absent          other               50.0
# 2                     NaN            normal         normal               33.0
# 3                     5.0         decreased            NaN               48.0
# 4                     NaN               NaN            NaN               74.0
# ..                    ...               ...            ...                ...
# 294                   NaN               NaN  distend_large               55.0
# 295                   NaN            absent  distend_small               44.0
# 296                   NaN         decreased  distend_large               60.0
# 297                   NaN            absent  distend_small               50.0
# 298                   NaN            absent         normal               36.0
#
#      total_protein abdomo_appearance abdomo_protein  outcome Class  \
# 0              8.4               NaN            NaN           died
# 1             85.0            cloudy            2.0     euthanized
# 2              6.7               NaN            NaN          lived
# 3              7.2     serosanguious            5.3           died
# 4              7.4               NaN            NaN           died
# ..             ...               ...            ...            ...
# 294           65.0               NaN            NaN     euthanized
# 295            NaN     serosanguious            3.3     euthanized
# 296            6.8               NaN            NaN           died
# 297            6.0     serosanguious            3.4          lived
# 298           62.0             clear            1.0     euthanized
#
#      surgical_lesion lesion
# 0                 no  11300
# 1                 no   2208
# 2                 no      0
# 3                yes   2208
# 4                 no   4300
# ..               ...    ...
# 294               no   3205
# 295              yes   2208
# 296              yes   3205
# 297              yes   2208
# 298               no   6112
#
# [299 rows x 24 columns]

# %%
def extract_lesion_column(lesion):
    site, type_l, subtype, code = 'None', 'None', 'None', 'None'
    if lesion != 0:
        types = re.findall('^([1-9]|11|00)([1-4])([0-2])([1-9]|10|0)',str(lesion))
        if types:
            site, type_l, subtype, code = types[0]
    return pd.Series({'site': site, 'type': type_l, 'subtype': subtype, 'code': code}, dtype='category')

df.loc[:, ['site', 'type', 'subtype', 'code']] = df.lesion.apply(extract_lesion_column).astype('category')
df.drop(columns='lesion', inplace=True)

# %%
categorical_columns = []
for col in df:
    if str(df[col].dtype) != 'category' and df[col].unique().size < 10:
        df[col].fillna('[NAN]', inplace=True)
        categorical_columns.append(col)
        df[col] = df[col].astype('category')

# %%
categorical_columns
# Out:
# ['surgery',
#  'age',
#  'temp_of_extremities',
#  'peripheral_pulse',
#  'mucous_membrane',
#  'capillary_refill_time',
#  'pain',
#  'peristalsis',
#  'abdominal_distention',
#  'nasogastric_tube',
#  'nasogastric_reflux',
#  'rectal_exam_feces',
#  'abdomen',
#  'abdomo_appearance',
#  'outcome Class',
#  'surgical_lesion']

# %%
X = []
X_labels = []
Y = None
for col in df:
    if col == 'outcome Class':
        Y = df[col].cat.codes.values
    elif str(df[col].dtype) != 'category':
        X.append(df[col].fillna(df[col].mean()).values,)
        X_labels.append(col)
    else:
        X.append(df[col].cat.codes.values)
        X_labels.append(col)
X = np.array(X)

# %%
selector = feature_selection.SelectPercentile(feature_selection.chi2,percentile=50).fit(X.T, Y)
top_k = selector.transform(X.T).shape[1]
[X_labels[i] for i in selector.scores_.argsort()[::-1]][:top_k]
# Out:
# ['total_protein',
#  'pulse',
#  'subtype',
#  'packed_cell_volume',
#  'site',
#  'code',
#  'abdomen',
#  'abdomo_appearance',
#  'respiratory_rate',
#  'rectal_exam_feces',
#  'type',
#  'temp_of_extremities',
#  'surgical_lesion']

# %%
selector = feature_selection.SelectPercentile(feature_selection.f_classif,percentile=50).fit(X.T, Y)
top_k = selector.transform(X.T).shape[1]
[X_labels[i] for i in selector.scores_.argsort()[::-1]][:top_k]
# Out:
# ['subtype',
#  'packed_cell_volume',
#  'total_protein',
#  'site',
#  'pulse',
#  'surgical_lesion',
#  'capillary_refill_time',
#  'temp_of_extremities',
#  'peristalsis',
#  'abdomo_protein',
#  'code',
#  'surgery',
#  'abdomo_appearance']

# %%
df.temp_of_extremities.value_counts()
# Out:
# cool      108
# normal     78
# [NAN]      56
# warm       30
# cold       27
# Name: temp_of_extremities, dtype: int64
