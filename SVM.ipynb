# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re

# %%
# Load data

# %%
df = pd.read_csv('./cow.csv')
df
# Out:
#     surgery    age  hospital_number  temperature  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 0                  cool          reduced             NaN
# 1                   NaN              NaN   pale_cyanotic
# 2                normal           normal       pale_pink
# 3                  cold           normal   dark_cyanotic
# 4                   NaN              NaN   dark_cyanotic
# ..                  ...              ...             ...
# 294                cold              NaN   pale_cyanotic
# 295                cool        increased   pale_cyanotic
# 296                cold          reduced   pale_cyanotic
# 297                cool          reduced       pale_pink
# 298                 NaN              NaN             NaN
#
#     capillary_refill_time  ... nasogastric_reflux_ph rectal_exam_feces  \
# 0              more_3_sec  ...                   NaN         decreased
# 1              less_3_sec  ...                   NaN            absent
# 2              less_3_sec  ...                   NaN            normal
# 3              more_3_sec  ...                   5.0         decreased
# 4              more_3_sec  ...                   NaN               NaN
# ..                    ...  ...                   ...               ...
# 294            more_3_sec  ...                   NaN               NaN
# 295            more_3_sec  ...                   NaN            absent
# 296            less_3_sec  ...                   NaN         decreased
# 297            less_3_sec  ...                   NaN            absent
# 298                   NaN  ...                   NaN            absent
#
#            abdomen packed_cell_volume total_protein  abdomo_appearance  \
# 0    distend_large               45.0           8.4                NaN
# 1            other               50.0          85.0             cloudy
# 2           normal               33.0           6.7                NaN
# 3              NaN               48.0           7.2      serosanguious
# 4              NaN               74.0           7.4                NaN
# ..             ...                ...           ...                ...
# 294  distend_large               55.0          65.0                NaN
# 295  distend_small               44.0           NaN      serosanguious
# 296  distend_large               60.0           6.8                NaN
# 297  distend_small               50.0           6.0      serosanguious
# 298         normal               36.0          62.0              clear
#
#     abdomo_protein outcome Class  surgical_lesion  lesion
# 0              NaN          died               no   11300
# 1              2.0    euthanized               no    2208
# 2              NaN         lived               no       0
# 3              5.3          died              yes    2208
# 4              NaN          died               no    4300
# ..             ...           ...              ...     ...
# 294            NaN    euthanized               no    3205
# 295            3.3    euthanized              yes    2208
# 296            NaN          died              yes    3205
# 297            3.4         lived              yes    2208
# 298            1.0    euthanized               no    6112
#
# [299 rows x 25 columns]

# %%
def extract_lesion_column(lesion):
    site, type_l, subtype, code = 'None', 'None', 'None', 'None'
    if lesion != 0:
        types = re.findall('^([1-9]|11|00)([1-4])([0-2])([1-9]|10|0)',str(lesion))
        if types:
            site, type_l, subtype, code = types[0]
    return pd.Series({'lesion_site': site, 'lesion_type': type_l, 'lesion_subtype': subtype, 'lesion_code': code}, dtype='category')

df.loc[:, ['lesion_site', 'lesion_type', 'lesion_subtype', 'lesion_code']] = df.lesion.apply(extract_lesion_column).astype('category')
df.drop(columns=['lesion', 'hospital_number'], inplace=True)

# %%
categorical_columns = []
for col in df:
    if str(df[col].dtype) != 'category' and df[col].unique().size < 10:
        df[col].fillna('[NAN]', inplace=True)
        categorical_columns.append(col)
        df[col] = df[col].astype('category')

# %%
X = []
X_labels = []
Y = None
for col in df:
    if col == 'outcome Class':
        Y = df[col].cat.codes.values
    elif str(df[col].dtype) != 'category':
        X.append(df[col].fillna(df[col].mean()).values,)
        X_labels.append(col)
    else:
        X.append(df[col].cat.codes.values)
        X_labels.append(col)
X = np.array(X).T
x_label2idx = {l:i for i,l in enumerate(X_labels)}

# %%
import sklearn.feature_selection as fs

# %%
selector = fs.SelectPercentile(fs.chi2,percentile=50).fit(X, Y)
X_new = selector.transform(X)
keep_cols = selector.scores_.argsort()[::-1][:X_new.shape[1]]
keep_cols_label = [X_labels[i] for i in keep_cols]
keep_cols_label
# Out:
# ['total_protein',
#  'pulse',
#  'lesion_subtype',
#  'packed_cell_volume',
#  'lesion_site',
#  'lesion_code',
#  'abdomen',
#  'abdomo_appearance',
#  'respiratory_rate',
#  'rectal_exam_feces',
#  'lesion_type',
#  'temp_of_extremities',
#  'surgical_lesion']

# %%
col2types = {l:df[l].dtype.name for l in X_labels}

# %%
from sklearn.model_selection import train_test_split
x_train_, x_test_, y_train_, y_test_ = train_test_split(X[:,keep_cols], Y, test_size=0.2)

# %%
np.unique(y_test_, return_counts=1),np.unique(y_train_, return_counts=1)
# Out:
# ((array([0, 1, 2], dtype=int8), array([18,  9, 33])),
#  (array([0, 1, 2], dtype=int8), array([ 59,  35, 145])))

# %%
num_classes = np.unique(y_test_).size
num_classes
# Out:
# 3

# %%
x_train_.T.shape
# Out:
# (13, 239)

# %%
x_train = x_train_ #{l:v for l, v in zip(keep_cols_label, x_train_.T)}
x_test = x_test_ #{l:v for l, v in zip(keep_cols_label, x_test_.T)}

y_train = y_train_ # tf.keras.utils.to_categorical(y_train_)
y_test = y_test_ # tf.keras.utils.to_categorical(y_test_)

# %% [markdown]
# # Buid model

# %%
from sklearn import svm
from sklearn.metrics import classification_report

# %%
outcome_classes = df['outcome Class'].cat.categories.tolist()

# %%
svm_modes = ['LinearSVC', 'SVC',]

# %%
def train_model(model):
    print(model)
    model.fit(x_train, y_train)
    test_hypo = model.predict(x_test)
    return classification_report(y_test, test_hypo, target_names=outcome_classes,output_dict=True)

# %%
results = {}
for loss in ['hinge', 'squared_hinge']:
    for multi_class in ['ovr', 'crammer_singer']:
        for C in range(1, 3):
            out = train_model(svm.LinearSVC(C=2, loss=loss))
            data = {}
            for k, v in out.items():
                if not isinstance(v, dict): continue
                if k not in ['lived', 'euthanized', 'died']: continue
                for k1, v1 in v.items():
                    if k1 in ['precision', 'recall']:
                        data[k1+'_'+k] = v1
            results[f'loss={loss}, multi_class={multi_class}, C={C}'] = data
# Out:
# LinearSVC(C=2, loss='hinge')
# LinearSVC(C=2, loss='hinge')
# LinearSVC(C=2, loss='hinge')
# LinearSVC(C=2, loss='hinge')
# LinearSVC(C=2)
# LinearSVC(C=2)
# LinearSVC(C=2)
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# LinearSVC(C=2)
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/napatswift/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
pd.DataFrame(results).T
# Out:
#                                                     precision_died  \
# loss=hinge, multi_class=ovr, C=1                          0.583333
# loss=hinge, multi_class=ovr, C=2                          0.750000
# loss=hinge, multi_class=crammer_singer, C=1               0.000000
# loss=hinge, multi_class=crammer_singer, C=2               0.400000
# loss=squared_hinge, multi_class=ovr, C=1                  0.450000
# loss=squared_hinge, multi_class=ovr, C=2                  1.000000
# loss=squared_hinge, multi_class=crammer_singer,...        1.000000
# loss=squared_hinge, multi_class=crammer_singer,...        0.800000
#
#                                                     recall_died  \
# loss=hinge, multi_class=ovr, C=1                       0.777778
# loss=hinge, multi_class=ovr, C=2                       0.500000
# loss=hinge, multi_class=crammer_singer, C=1            0.000000
# loss=hinge, multi_class=crammer_singer, C=2            1.000000
# loss=squared_hinge, multi_class=ovr, C=1               0.500000
# loss=squared_hinge, multi_class=ovr, C=2               0.055556
# loss=squared_hinge, multi_class=crammer_singer,...     0.055556
# loss=squared_hinge, multi_class=crammer_singer,...     0.222222
#
#                                                     precision_euthanized  \
# loss=hinge, multi_class=ovr, C=1                                1.000000
# loss=hinge, multi_class=ovr, C=2                                0.555556
# loss=hinge, multi_class=crammer_singer, C=1                     1.000000
# loss=hinge, multi_class=crammer_singer, C=2                     1.000000
# loss=squared_hinge, multi_class=ovr, C=1                        0.272727
# loss=squared_hinge, multi_class=ovr, C=2                        0.250000
# loss=squared_hinge, multi_class=crammer_singer,...              0.000000
# loss=squared_hinge, multi_class=crammer_singer,...              0.000000
#
#                                                     recall_euthanized  \
# loss=hinge, multi_class=ovr, C=1                             0.111111
# loss=hinge, multi_class=ovr, C=2                             0.555556
# loss=hinge, multi_class=crammer_singer, C=1                  0.333333
# loss=hinge, multi_class=crammer_singer, C=2                  0.111111
# loss=squared_hinge, multi_class=ovr, C=1                     0.666667
# loss=squared_hinge, multi_class=ovr, C=2                     0.888889
# loss=squared_hinge, multi_class=crammer_singer,...           0.000000
# loss=squared_hinge, multi_class=crammer_singer,...           0.000000
#
#                                                     precision_lived  \
# loss=hinge, multi_class=ovr, C=1                           0.800000
# loss=hinge, multi_class=ovr, C=2                           0.769231
# loss=hinge, multi_class=crammer_singer, C=1                0.578947
# loss=hinge, multi_class=crammer_singer, C=2                0.928571
# loss=squared_hinge, multi_class=ovr, C=1                   0.888889
# loss=squared_hinge, multi_class=ovr, C=2                   0.814815
# loss=squared_hinge, multi_class=crammer_singer,...         0.559322
# loss=squared_hinge, multi_class=crammer_singer,...         0.600000
#
#                                                     recall_lived
# loss=hinge, multi_class=ovr, C=1                        0.848485
# loss=hinge, multi_class=ovr, C=2                        0.909091
# loss=hinge, multi_class=crammer_singer, C=1             1.000000
# loss=hinge, multi_class=crammer_singer, C=2             0.393939
# loss=squared_hinge, multi_class=ovr, C=1                0.484848
# loss=squared_hinge, multi_class=ovr, C=2                0.666667
# loss=squared_hinge, multi_class=crammer_singer,...      1.000000
# loss=squared_hinge, multi_class=crammer_singer,...      1.000000
